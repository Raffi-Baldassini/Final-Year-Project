# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import Pipeline
from pandas.plotting import scatter_matrix
from seaborn import scatterplot

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dfTrain = pd.read_csv('../Data/train.csv', encoding = 'utf-8', lineterminator="\n")
targetValues = dfTrain['target'].to_frame()
targetValues.columns = ['Values']

# %%
dfPOS = pd.read_csv('../Data/POS_Columns.csv', encoding = 'utf-8', lineterminator="\n")

# %%
cols = ['Index', 'Sents', 'Words', 'C_W_C', 'S_C',
                'ADJ', 'ADP', 'ADV', 'AUX', 'CCONJ', 'DET','INTJ', 'NOUN', 
                'NUM', 'PART', 'PRON','PROPN', 'PUNCT','SCONJ','SYM','VERB','X']
dfPOS.columns = cols
dfPOS = dfPOS.drop(['Index'], axis = 1)
dfPOS = dfPOS.drop(['X'], axis = 1)

# %%
pCorr = dfPOS.corr(method='pearson')

# %%
pCorr
# Out:
#           Sents     Words     C_W_C       S_C       ADJ       ADP       ADV  \
# Sents  1.000000  0.246253 -0.172172 -0.013029 -0.111711 -0.324174  0.043229
# Words  0.246253  1.000000  0.117852  0.606382  0.195407  0.335980  0.265731
# C_W_C -0.172172  0.117852  1.000000  0.827403  0.425889  0.299289 -0.219754
# S_C   -0.013029  0.606382  0.827403  1.000000  0.471324  0.425044 -0.042571
# ADJ   -0.111711  0.195407  0.425889  0.471324  1.000000  0.190039 -0.068978
# ADP   -0.324174  0.335980  0.299289  0.425044  0.190039  1.000000 -0.128090
# ADV    0.043229  0.265731 -0.219754 -0.042571 -0.068978 -0.128090  1.000000
# AUX    0.223342  0.293300 -0.005326  0.113889 -0.014330 -0.178734  0.174791
# CCONJ -0.180789  0.198870 -0.119131  0.010496  0.064155 -0.021836  0.164826
# DET   -0.076608  0.328431  0.090916  0.247594  0.056729  0.402948 -0.156129
# INTJ   0.265827  0.079937 -0.263091 -0.182929 -0.143466 -0.217973  0.151865
# NOUN   0.034673  0.296995  0.540588  0.611888  0.291807  0.332543 -0.308559
# NUM    0.001979  0.081913  0.091749  0.130675  0.028198  0.185291 -0.074431
# PART   0.210081  0.210678 -0.163032 -0.058851 -0.214705 -0.310495  0.135882
# PRON   0.252799  0.242022 -0.531716 -0.346052 -0.327493 -0.308484  0.344881
# PROPN  0.141487  0.055043  0.007983  0.045041 -0.066487  0.042173 -0.115519
# PUNCT  0.508842  0.307742 -0.246193 -0.041323 -0.103678 -0.245940  0.199838
# SCONJ -0.155351  0.199152 -0.092147  0.008125 -0.145838 -0.173484  0.241404
# SYM    0.003420  0.027631  0.134699  0.119011  0.064087  0.060652 -0.058837
# VERB   0.456046  0.392869 -0.307361 -0.047118 -0.367961 -0.358274  0.228901
#
#             AUX     CCONJ       DET      INTJ      NOUN       NUM      PART  \
# Sents  0.223342 -0.180789 -0.076608  0.265827  0.034673  0.001979  0.210081
# Words  0.293300  0.198870  0.328431  0.079937  0.296995  0.081913  0.210678
# C_W_C -0.005326 -0.119131  0.090916 -0.263091  0.540588  0.091749 -0.163032
# S_C    0.113889  0.010496  0.247594 -0.182929  0.611888  0.130675 -0.058851
# ADJ   -0.014330  0.064155  0.056729 -0.143466  0.291807  0.028198 -0.214705
# ADP   -0.178734 -0.021836  0.402948 -0.217973  0.332543  0.185291 -0.310495
# ADV    0.174791  0.164826 -0.156129  0.151865 -0.308559 -0.074431  0.135882
# AUX    1.000000 -0.108271 -0.088659  0.095186 -0.098632 -0.070132  0.222018
# CCONJ -0.108271  1.000000 -0.097513  0.020034 -0.002898 -0.105526 -0.047073
# DET   -0.088659 -0.097513  1.000000 -0.112179  0.296673  0.048804 -0.226566
# INTJ   0.095186  0.020034 -0.112179  1.000000 -0.227616 -0.073534  0.121812
# NOUN  -0.098632 -0.002898  0.296673 -0.227616  1.000000  0.092788 -0.226290
# NUM   -0.070132 -0.105526  0.048804 -0.073534  0.092788  1.000000 -0.185360
# PART   0.222018 -0.047073 -0.226566  0.121812 -0.226290 -0.185360  1.000000
# PRON   0.223002  0.111496 -0.312937  0.303240 -0.527665 -0.256302  0.355420
# PROPN -0.064983 -0.072595 -0.042902  0.051272 -0.343424  0.177839  0.028710
# PUNCT  0.100880  0.100358 -0.115700  0.480196 -0.081853  0.015676  0.119034
# SCONJ  0.254378 -0.053034 -0.112371 -0.016585 -0.194810 -0.139644  0.246145
# SYM    0.000528 -0.081403 -0.029925 -0.041318  0.126286  0.367256 -0.075661
# VERB   0.100590  0.065927 -0.127061  0.274412 -0.191376 -0.205047  0.476195
#
#            PRON     PROPN     PUNCT     SCONJ       SYM      VERB
# Sents  0.252799  0.141487  0.508842 -0.155351  0.003420  0.456046
# Words  0.242022  0.055043  0.307742  0.199152  0.027631  0.392869
# C_W_C -0.531716  0.007983 -0.246193 -0.092147  0.134699 -0.307361
# S_C   -0.346052  0.045041 -0.041323  0.008125  0.119011 -0.047118
# ADJ   -0.327493 -0.066487 -0.103678 -0.145838  0.064087 -0.367961
# ADP   -0.308484  0.042173 -0.245940 -0.173484  0.060652 -0.358274
# ADV    0.344881 -0.115519  0.199838  0.241404 -0.058837  0.228901
# AUX    0.223002 -0.064983  0.100880  0.254378  0.000528  0.100590
# CCONJ  0.111496 -0.072595  0.100358 -0.053034 -0.081403  0.065927
# DET   -0.312937 -0.042902 -0.115700 -0.112371 -0.029925 -0.127061
# INTJ   0.303240  0.051272  0.480196 -0.016585 -0.041318  0.274412
# NOUN  -0.527665 -0.343424 -0.081853 -0.194810  0.126286 -0.191376
# NUM   -0.256302  0.177839  0.015676 -0.139644  0.367256 -0.205047
# PART   0.355420  0.028710  0.119034  0.246145 -0.075661  0.476195
# PRON   1.000000 -0.076545  0.367884  0.283847 -0.169444  0.537506
# PROPN -0.076545  1.000000  0.161240 -0.167259  0.017437 -0.058884
# PUNCT  0.367884  0.161240  1.000000 -0.125863 -0.010375  0.425398
# SCONJ  0.283847 -0.167259 -0.125863  1.000000 -0.060387  0.312443
# SYM   -0.169444  0.017437 -0.010375 -0.060387  1.000000 -0.117150
# VERB   0.537506 -0.058884  0.425398  0.312443 -0.117150  1.000000

# %%
currCols = [cols[i] for i in range(1,len(cols)-1)]

# %%
for column in currCols:
    temp = dfPOS[column].to_frame().join(targetValues)
    print(temp.corr(method='pearson'))
# Out:
#            Sents    Values
# Sents   1.000000  0.357732
# Values  0.357732  1.000000
#            Words    Values
# Words   1.000000 -0.120652
# Values -0.120652  1.000000
#            C_W_C    Values
# C_W_C   1.000000 -0.490845
# Values -0.490845  1.000000
#              S_C    Values
# S_C     1.000000 -0.455607
# Values -0.455607  1.000000
#              ADJ    Values
# ADJ     1.000000 -0.238013
# Values -0.238013  1.000000
#              ADP    Values
# ADP     1.000000 -0.443499
# Values -0.443499  1.000000
#              ADV    Values
# ADV     1.000000  0.105781
# Values  0.105781  1.000000
#              AUX    Values
# AUX     1.000000  0.029233
# Values  0.029233  1.000000
#            CCONJ    Values
# CCONJ   1.000000  0.014322
# Values  0.014322  1.000000
#              DET    Values
# DET     1.000000 -0.216317
# Values -0.216317  1.000000
#             INTJ    Values
# INTJ    1.000000  0.223467
# Values  0.223467  1.000000
#             NOUN    Values
# NOUN    1.000000 -0.247965
# Values -0.247965  1.000000
#              NUM    Values
# NUM     1.000000 -0.143554
# Values -0.143554  1.000000
#             PART    Values
# PART    1.000000  0.202417
# Values  0.202417  1.000000
#             PRON    Values
# PRON    1.000000  0.314899
# Values  0.314899  1.000000
#            PROPN    Values
# PROPN   1.000000 -0.041869
# Values -0.041869  1.000000
#            PUNCT    Values
# PUNCT   1.000000  0.208008
# Values  0.208008  1.000000
#            SCONJ    Values
# SCONJ   1.000000  0.063196
# Values  0.063196  1.000000
#              SYM    Values
# SYM     1.000000 -0.066417
# Values -0.066417  1.000000
#             VERB    Values
# VERB    1.000000  0.356679
# Values  0.356679  1.000000

# %%
for column in currCols:
    temp = dfPOS[column].to_frame().join(targetValues)
    print(temp.corr(method='spearman'))
# Out:
#            Sents    Values
# Sents   1.000000  0.356976
# Values  0.356976  1.000000
#            Words    Values
# Words   1.000000 -0.114061
# Values -0.114061  1.000000
#            C_W_C    Values
# C_W_C   1.000000 -0.507945
# Values -0.507945  1.000000
#              S_C    Values
# S_C     1.000000 -0.451144
# Values -0.451144  1.000000
#              ADJ    Values
# ADJ     1.000000 -0.244622
# Values -0.244622  1.000000
#              ADP    Values
# ADP     1.000000 -0.445923
# Values -0.445923  1.000000
#              ADV    Values
# ADV     1.000000  0.119014
# Values  0.119014  1.000000
#              AUX    Values
# AUX     1.000000  0.029198
# Values  0.029198  1.000000
#            CCONJ    Values
# CCONJ   1.000000  0.005472
# Values  0.005472  1.000000
#              DET    Values
# DET     1.000000 -0.209667
# Values -0.209667  1.000000
#             INTJ    Values
# INTJ    1.000000  0.253601
# Values  0.253601  1.000000
#             NOUN    Values
# NOUN    1.000000 -0.250892
# Values -0.250892  1.000000
#              NUM    Values
# NUM     1.000000 -0.095804
# Values -0.095804  1.000000
#             PART    Values
# PART    1.000000  0.207073
# Values  0.207073  1.000000
#             PRON    Values
# PRON    1.000000  0.318632
# Values  0.318632  1.000000
#            PROPN    Values
# PROPN   1.000000 -0.030771
# Values -0.030771  1.000000
#           PUNCT   Values
# PUNCT   1.00000  0.17925
# Values  0.17925  1.00000
#            SCONJ    Values
# SCONJ   1.000000  0.067691
# Values  0.067691  1.000000
#              SYM    Values
# SYM     1.000000 -0.074001
# Values -0.074001  1.000000
#             VERB    Values
# VERB    1.000000  0.358587
# Values  0.358587  1.000000

# %%
m = scatter_matrix(dfPOS.join(targetValues), figsize=(15, 15))

# %%
pca = PCA()

# %%
pca.fit(dfPOS)

# %%
pca.explained_variance_ratio_

# %%
LR = Pipeline(steps =[('scaler', StandardScaler()), ('linear_regressor',  LinearRegression())])
PCR = Pipeline(steps =[('scaler', StandardScaler()), ('pca', PCA(n_components=3)), ('linear_regressor',  LinearRegression())])

# %%
PCR.fit(dfPOS, targetValues)

# %%
LR_scores = cross_val_score(LR, dfPOS, targetValues,scoring="neg_mean_absolute_error", cv=10)
LR_scores = -LR_scores
print(f"Linear Regression\nScores:\n{LR_scores}\nMean:{LR_scores.mean()}\nSTD:{LR_scores.std()}")

# %%
pca_scores = cross_val_score(PCR, dfPOS, targetValues, scoring="neg_mean_absolute_error", cv=10)

# %%
print(f"PCA Regression\nScores:\n{-pca_scores}\nMean:{-pca_scores.mean()}\nSTD:{pca_scores.std()}")

# %%
param_grid = {
    "pca__n_components": [1, 5, 10, 15, 20],
}

# %%
search = GridSearchCV(PCR, param_grid, scoring="neg_mean_absolute_error", cv=10)

# %%
search.fit(dfPOS, targetValues)
print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)
search.cv_results_
