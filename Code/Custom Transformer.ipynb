# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import syllables
import re
import stanza
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, r2_score

# %%
class TextExcerptExtractor(BaseEstimator,TransformerMixin):
    def __init__(self):
        self = self
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        X = X['excerpt']

# %%
stanza.download('en', logging_level='WARN')
nlp = stanza.Pipeline('en', logging_level='WARN')

# %%
df = pd.read_csv('../Data/train.csv', encoding = 'utf-8', lineterminator="\n")

# %%
feature = ['excerpt']

X = df[feature].values

# %%
sent = str(X[1])[2:-2].replace('\\r\\n', '')

# %%
doc = nlp(sent)

# %%
for sentence in doc.sentences:
    pos = []
    print(sentence)
    for word in sentence.words:
        pos.append(word.pos)
    print(pos)
# Out:
# [
#   {
#     "id": 1,
#     "text": "All",
#     "lemma": "all",
#     "upos": "DET",
#     "xpos": "DT",
#     "head": 10,
#     "deprel": "advmod",
#     "start_char": 0,
#     "end_char": 3,
#     "ner": "O"
#   },
#   {
#     "id": 2,
#     "text": "through",
#     "lemma": "through",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 4,
#     "deprel": "case",
#     "start_char": 4,
#     "end_char": 11,
#     "ner": "O"
#   },
#   {
#     "id": 3,
#     "text": "dinner",
#     "lemma": "dinner",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 4,
#     "deprel": "compound",
#     "start_char": 12,
#     "end_char": 18,
#     "ner": "O"
#   },
#   {
#     "id": 4,
#     "text": "time",
#     "lemma": "time",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 1,
#     "deprel": "nmod",
#     "start_char": 19,
#     "end_char": 23,
#     "ner": "O"
#   },
#   {
#     "id": 5,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 10,
#     "deprel": "punct",
#     "start_char": 23,
#     "end_char": 24,
#     "ner": "O"
#   },
#   {
#     "id": 6,
#     "text": "Mrs.",
#     "lemma": "Mrs.",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "feats": "Number=Sing",
#     "head": 10,
#     "deprel": "nsubj",
#     "start_char": 25,
#     "end_char": 29,
#     "ner": "O"
#   },
#   {
#     "id": 7,
#     "text": "Fayre",
#     "lemma": "Fayre",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "feats": "Number=Sing",
#     "head": 6,
#     "deprel": "flat",
#     "start_char": 30,
#     "end_char": 35,
#     "ner": "S-PERSON"
#   },
#   {
#     "id": 8,
#     "text": "was",
#     "lemma": "be",
#     "upos": "AUX",
#     "xpos": "VBD",
#     "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#     "head": 10,
#     "deprel": "cop",
#     "start_char": 36,
#     "end_char": 39,
#     "ner": "O"
#   },
#   {
#     "id": 9,
#     "text": "somewhat",
#     "lemma": "somewhat",
#     "upos": "ADV",
#     "xpos": "RB",
#     "head": 10,
#     "deprel": "advmod",
#     "start_char": 40,
#     "end_char": 48,
#     "ner": "O"
#   },
#   {
#     "id": 10,
#     "text": "silent",
#     "lemma": "silent",
#     "upos": "ADJ",
#     "xpos": "JJ",
#     "feats": "Degree=Pos",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 49,
#     "end_char": 55,
#     "ner": "O"
#   },
#   {
#     "id": 11,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 10,
#     "deprel": "punct",
#     "start_char": 55,
#     "end_char": 56,
#     "ner": "O"
#   },
#   {
#     "id": 12,
#     "text": "her",
#     "lemma": "she",
#     "upos": "PRON",
#     "xpos": "PRP$",
#     "feats": "Gender=Fem|Number=Sing|Person=3|Poss=Yes|PronType=Prs",
#     "head": 13,
#     "deprel": "nmod:poss",
#     "start_char": 57,
#     "end_char": 60,
#     "ner": "O"
#   },
#   {
#     "id": 13,
#     "text": "eyes",
#     "lemma": "eye",
#     "upos": "NOUN",
#     "xpos": "NNS",
#     "feats": "Number=Plur",
#     "head": 10,
#     "deprel": "nsubj",
#     "start_char": 61,
#     "end_char": 65,
#     "ner": "O"
#   },
#   {
#     "id": 14,
#     "text": "resting",
#     "lemma": "rest",
#     "upos": "VERB",
#     "xpos": "VBG",
#     "feats": "VerbForm=Ger",
#     "head": 10,
#     "deprel": "advcl",
#     "start_char": 66,
#     "end_char": 73,
#     "ner": "O"
#   },
#   {
#     "id": 15,
#     "text": "on",
#     "lemma": "on",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 16,
#     "deprel": "case",
#     "start_char": 74,
#     "end_char": 76,
#     "ner": "O"
#   },
#   {
#     "id": 16,
#     "text": "Dolly",
#     "lemma": "Dolly",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "feats": "Number=Sing",
#     "head": 14,
#     "deprel": "obl",
#     "start_char": 77,
#     "end_char": 82,
#     "ner": "S-PERSON"
#   },
#   {
#     "id": 17,
#     "text": "with",
#     "lemma": "with",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 22,
#     "deprel": "case",
#     "start_char": 83,
#     "end_char": 87,
#     "ner": "O"
#   },
#   {
#     "id": 18,
#     "text": "a",
#     "lemma": "a",
#     "upos": "DET",
#     "xpos": "DT",
#     "feats": "Definite=Ind|PronType=Art",
#     "head": 22,
#     "deprel": "det",
#     "start_char": 88,
#     "end_char": 89,
#     "ner": "O"
#   },
#   {
#     "id": 19,
#     "text": "wistful",
#     "lemma": "wistful",
#     "upos": "ADJ",
#     "xpos": "JJ",
#     "feats": "Degree=Pos",
#     "head": 22,
#     "deprel": "amod",
#     "start_char": 90,
#     "end_char": 97,
#     "ner": "O"
#   },
#   {
#     "id": 20,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 22,
#     "deprel": "punct",
#     "start_char": 97,
#     "end_char": 98,
#     "ner": "O"
#   },
#   {
#     "id": 21,
#     "text": "uncertain",
#     "lemma": "uncertain",
#     "upos": "ADJ",
#     "xpos": "JJ",
#     "feats": "Degree=Pos",
#     "head": 22,
#     "deprel": "amod",
#     "start_char": 99,
#     "end_char": 108,
#     "ner": "O"
#   },
#   {
#     "id": 22,
#     "text": "expression",
#     "lemma": "expression",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 14,
#     "deprel": "obl",
#     "start_char": 109,
#     "end_char": 119,
#     "ner": "O"
#   },
#   {
#     "id": 23,
#     "text": ".",
#     "lemma": ".",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 10,
#     "deprel": "punct",
#     "start_char": 119,
#     "end_char": 120,
#     "ner": "O"
#   }
# ]
# ['DET', 'ADP', 'NOUN', 'NOUN', 'PUNCT', 'PROPN', 'PROPN', 'AUX', 'ADV', 'ADJ', 'PUNCT', 'PRON', 'NOUN', 'VERB', 'ADP', 'PROPN', 'ADP', 'DET', 'ADJ', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT']
# [
#   {
#     "id": 1,
#     "text": "She",
#     "lemma": "she",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs",
#     "head": 2,
#     "deprel": "nsubj",
#     "start_char": 121,
#     "end_char": 124,
#     "ner": "O"
#   },
#   {
#     "id": 2,
#     "text": "wanted",
#     "lemma": "want",
#     "upos": "VERB",
#     "xpos": "VBD",
#     "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 125,
#     "end_char": 131,
#     "ner": "O"
#   },
#   {
#     "id": 3,
#     "text": "to",
#     "lemma": "to",
#     "upos": "PART",
#     "xpos": "TO",
#     "head": 4,
#     "deprel": "mark",
#     "start_char": 132,
#     "end_char": 134,
#     "ner": "O"
#   },
#   {
#     "id": 4,
#     "text": "give",
#     "lemma": "give",
#     "upos": "VERB",
#     "xpos": "VB",
#     "feats": "VerbForm=Inf",
#     "head": 2,
#     "deprel": "xcomp",
#     "start_char": 135,
#     "end_char": 139,
#     "ner": "O"
#   },
#   {
#     "id": 5,
#     "text": "the",
#     "lemma": "the",
#     "upos": "DET",
#     "xpos": "DT",
#     "feats": "Definite=Def|PronType=Art",
#     "head": 6,
#     "deprel": "det",
#     "start_char": 140,
#     "end_char": 143,
#     "ner": "O"
#   },
#   {
#     "id": 6,
#     "text": "child",
#     "lemma": "child",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 4,
#     "deprel": "iobj",
#     "start_char": 144,
#     "end_char": 149,
#     "ner": "O"
#   },
#   {
#     "id": 7,
#     "text": "the",
#     "lemma": "the",
#     "upos": "DET",
#     "xpos": "DT",
#     "feats": "Definite=Def|PronType=Art",
#     "head": 8,
#     "deprel": "det",
#     "start_char": 150,
#     "end_char": 153,
#     "ner": "O"
#   },
#   {
#     "id": 8,
#     "text": "pleasure",
#     "lemma": "pleasure",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 4,
#     "deprel": "obj",
#     "start_char": 154,
#     "end_char": 162,
#     "ner": "O"
#   },
#   {
#     "id": 9,
#     "text": "she",
#     "lemma": "she",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs",
#     "head": 10,
#     "deprel": "nsubj",
#     "start_char": 163,
#     "end_char": 166,
#     "ner": "O"
#   },
#   {
#     "id": 10,
#     "text": "craved",
#     "lemma": "crave",
#     "upos": "VERB",
#     "xpos": "VBD",
#     "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#     "head": 8,
#     "deprel": "acl:relcl",
#     "start_char": 167,
#     "end_char": 173,
#     "ner": "O"
#   },
#   {
#     "id": 11,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 14,
#     "deprel": "punct",
#     "start_char": 173,
#     "end_char": 174,
#     "ner": "O"
#   },
#   {
#     "id": 12,
#     "text": "but",
#     "lemma": "but",
#     "upos": "CCONJ",
#     "xpos": "CC",
#     "head": 14,
#     "deprel": "cc",
#     "start_char": 175,
#     "end_char": 178,
#     "ner": "O"
#   },
#   {
#     "id": 13,
#     "text": "she",
#     "lemma": "she",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs",
#     "head": 14,
#     "deprel": "nsubj",
#     "start_char": 179,
#     "end_char": 182,
#     "ner": "O"
#   },
#   {
#     "id": 14,
#     "text": "had",
#     "lemma": "have",
#     "upos": "VERB",
#     "xpos": "VBD",
#     "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#     "head": 2,
#     "deprel": "conj",
#     "start_char": 183,
#     "end_char": 186,
#     "ner": "O"
#   },
#   {
#     "id": 15,
#     "text": "hard",
#     "lemma": "hard",
#     "upos": "ADJ",
#     "xpos": "JJ",
#     "feats": "Degree=Pos",
#     "head": 16,
#     "deprel": "amod",
#     "start_char": 187,
#     "end_char": 191,
#     "ner": "O"
#   },
#   {
#     "id": 16,
#     "text": "work",
#     "lemma": "work",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 14,
#     "deprel": "obj",
#     "start_char": 192,
#     "end_char": 196,
#     "ner": "O"
#   },
#   {
#     "id": 17,
#     "text": "to",
#     "lemma": "to",
#     "upos": "PART",
#     "xpos": "TO",
#     "head": 18,
#     "deprel": "mark",
#     "start_char": 197,
#     "end_char": 199,
#     "ner": "O"
#   },
#   {
#     "id": 18,
#     "text": "bring",
#     "lemma": "bring",
#     "upos": "VERB",
#     "xpos": "VB",
#     "feats": "VerbForm=Inf",
#     "head": 16,
#     "deprel": "acl",
#     "start_char": 200,
#     "end_char": 205,
#     "ner": "O"
#   },
#   {
#     "id": 19,
#     "text": "herself",
#     "lemma": "herself",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Acc|Gender=Masc|Number=Sing|Person=3|PronType=Prs|Reflex=Yes",
#     "head": 18,
#     "deprel": "obj",
#     "start_char": 206,
#     "end_char": 213,
#     "ner": "O"
#   },
#   {
#     "id": 20,
#     "text": "to",
#     "lemma": "to",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 22,
#     "deprel": "case",
#     "start_char": 214,
#     "end_char": 216,
#     "ner": "O"
#   },
#   {
#     "id": 21,
#     "text": "the",
#     "lemma": "the",
#     "upos": "DET",
#     "xpos": "DT",
#     "feats": "Definite=Def|PronType=Art",
#     "head": 22,
#     "deprel": "det",
#     "start_char": 217,
#     "end_char": 220,
#     "ner": "O"
#   },
#   {
#     "id": 22,
#     "text": "point",
#     "lemma": "point",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 18,
#     "deprel": "obl",
#     "start_char": 221,
#     "end_char": 226,
#     "ner": "O"
#   },
#   {
#     "id": 23,
#     "text": "of",
#     "lemma": "of",
#     "upos": "SCONJ",
#     "xpos": "IN",
#     "head": 24,
#     "deprel": "mark",
#     "start_char": 227,
#     "end_char": 229,
#     "ner": "O"
#   },
#   {
#     "id": 24,
#     "text": "overcoming",
#     "lemma": "overcome",
#     "upos": "VERB",
#     "xpos": "VBG",
#     "feats": "VerbForm=Ger",
#     "head": 22,
#     "deprel": "acl",
#     "start_char": 230,
#     "end_char": 240,
#     "ner": "O"
#   },
#   {
#     "id": 25,
#     "text": "her",
#     "lemma": "she",
#     "upos": "PRON",
#     "xpos": "PRP$",
#     "feats": "Gender=Fem|Number=Sing|Person=3|Poss=Yes|PronType=Prs",
#     "head": 27,
#     "deprel": "nmod:poss",
#     "start_char": 241,
#     "end_char": 244,
#     "ner": "O"
#   },
#   {
#     "id": 26,
#     "text": "own",
#     "lemma": "own",
#     "upos": "ADJ",
#     "xpos": "JJ",
#     "feats": "Degree=Pos",
#     "head": 27,
#     "deprel": "amod",
#     "start_char": 245,
#     "end_char": 248,
#     "ner": "O"
#   },
#   {
#     "id": 27,
#     "text": "objections",
#     "lemma": "objection",
#     "upos": "NOUN",
#     "xpos": "NNS",
#     "feats": "Number=Plur",
#     "head": 24,
#     "deprel": "obj",
#     "start_char": 249,
#     "end_char": 259,
#     "ner": "O"
#   },
#   {
#     "id": 28,
#     "text": ".",
#     "lemma": ".",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 2,
#     "deprel": "punct",
#     "start_char": 259,
#     "end_char": 260,
#     "ner": "O"
#   }
# ]
# ['PRON', 'VERB', 'PART', 'VERB', 'DET', 'NOUN', 'DET', 'NOUN', 'PRON', 'VERB', 'PUNCT', 'CCONJ', 'PRON', 'VERB', 'ADJ', 'NOUN', 'PART', 'VERB', 'PRON', 'ADP', 'DET', 'NOUN', 'SCONJ', 'VERB', 'PRON', 'ADJ', 'NOUN', 'PUNCT']
# [
#   {
#     "id": 1,
#     "text": "At",
#     "lemma": "at",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 2,
#     "deprel": "case",
#     "start_char": 260,
#     "end_char": 262,
#     "ner": "O"
#   },
#   {
#     "id": 2,
#     "text": "last",
#     "lemma": "last",
#     "upos": "ADJ",
#     "xpos": "JJ",
#     "feats": "Degree=Pos",
#     "head": 14,
#     "deprel": "obl",
#     "start_char": 263,
#     "end_char": 267,
#     "ner": "O"
#   },
#   {
#     "id": 3,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 14,
#     "deprel": "punct",
#     "start_char": 267,
#     "end_char": 268,
#     "ner": "O"
#   },
#   {
#     "id": 4,
#     "text": "however",
#     "lemma": "however",
#     "upos": "ADV",
#     "xpos": "RB",
#     "head": 14,
#     "deprel": "advmod",
#     "start_char": 269,
#     "end_char": 276,
#     "ner": "O"
#   },
#   {
#     "id": 5,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 14,
#     "deprel": "punct",
#     "start_char": 276,
#     "end_char": 277,
#     "ner": "O"
#   },
#   {
#     "id": 6,
#     "text": "when",
#     "lemma": "when",
#     "upos": "SCONJ",
#     "xpos": "WRB",
#     "feats": "PronType=Int",
#     "head": 11,
#     "deprel": "mark",
#     "start_char": 278,
#     "end_char": 282,
#     "ner": "O"
#   },
#   {
#     "id": 7,
#     "text": "the",
#     "lemma": "the",
#     "upos": "DET",
#     "xpos": "DT",
#     "feats": "Definite=Def|PronType=Art",
#     "head": 8,
#     "deprel": "det",
#     "start_char": 283,
#     "end_char": 286,
#     "ner": "O"
#   },
#   {
#     "id": 8,
#     "text": "meal",
#     "lemma": "meal",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 11,
#     "deprel": "nsubj",
#     "start_char": 287,
#     "end_char": 291,
#     "ner": "O"
#   },
#   {
#     "id": 9,
#     "text": "was",
#     "lemma": "be",
#     "upos": "AUX",
#     "xpos": "VBD",
#     "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#     "head": 11,
#     "deprel": "cop",
#     "start_char": 292,
#     "end_char": 295,
#     "ner": "O"
#   },
#   {
#     "id": 10,
#     "text": "nearly",
#     "lemma": "nearly",
#     "upos": "ADV",
#     "xpos": "RB",
#     "feats": "Degree=Pos",
#     "head": 11,
#     "deprel": "advmod",
#     "start_char": 296,
#     "end_char": 302,
#     "ner": "O"
#   },
#   {
#     "id": 11,
#     "text": "over",
#     "lemma": "over",
#     "upos": "ADV",
#     "xpos": "RB",
#     "head": 14,
#     "deprel": "advcl",
#     "start_char": 303,
#     "end_char": 307,
#     "ner": "O"
#   },
#   {
#     "id": 12,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 11,
#     "deprel": "punct",
#     "start_char": 307,
#     "end_char": 308,
#     "ner": "O"
#   },
#   {
#     "id": 13,
#     "text": "she",
#     "lemma": "she",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Gender=Fem|Number=Sing|Person=3|PronType=Prs",
#     "head": 14,
#     "deprel": "nsubj",
#     "start_char": 309,
#     "end_char": 312,
#     "ner": "O"
#   },
#   {
#     "id": 14,
#     "text": "smiled",
#     "lemma": "smile",
#     "upos": "VERB",
#     "xpos": "VBD",
#     "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 313,
#     "end_char": 319,
#     "ner": "O"
#   },
#   {
#     "id": 15,
#     "text": "at",
#     "lemma": "at",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 18,
#     "deprel": "case",
#     "start_char": 320,
#     "end_char": 322,
#     "ner": "O"
#   },
#   {
#     "id": 16,
#     "text": "her",
#     "lemma": "she",
#     "upos": "PRON",
#     "xpos": "PRP$",
#     "feats": "Gender=Fem|Number=Sing|Person=3|Poss=Yes|PronType=Prs",
#     "head": 18,
#     "deprel": "nmod:poss",
#     "start_char": 323,
#     "end_char": 326,
#     "ner": "O"
#   },
#   {
#     "id": 17,
#     "text": "little",
#     "lemma": "little",
#     "upos": "ADJ",
#     "xpos": "JJ",
#     "feats": "Degree=Pos",
#     "head": 18,
#     "deprel": "amod",
#     "start_char": 327,
#     "end_char": 333,
#     "ner": "O"
#   },
#   {
#     "id": 18,
#     "text": "daughter",
#     "lemma": "daughter",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 14,
#     "deprel": "obl",
#     "start_char": 334,
#     "end_char": 342,
#     "ner": "O"
#   },
#   {
#     "id": 19,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 21,
#     "deprel": "punct",
#     "start_char": 342,
#     "end_char": 343,
#     "ner": "O"
#   },
#   {
#     "id": 20,
#     "text": "and",
#     "lemma": "and",
#     "upos": "CCONJ",
#     "xpos": "CC",
#     "head": 21,
#     "deprel": "cc",
#     "start_char": 344,
#     "end_char": 347,
#     "ner": "O"
#   },
#   {
#     "id": 21,
#     "text": "said",
#     "lemma": "say",
#     "upos": "VERB",
#     "xpos": "VBD",
#     "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#     "head": 14,
#     "deprel": "conj",
#     "start_char": 348,
#     "end_char": 352,
#     "ner": "O"
#   },
#   {
#     "id": 22,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 31,
#     "deprel": "punct",
#     "start_char": 352,
#     "end_char": 353,
#     "ner": "O"
#   },
#   {
#     "id": 23,
#     "text": "\"",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "xpos": "``",
#     "head": 31,
#     "deprel": "punct",
#     "start_char": 354,
#     "end_char": 355,
#     "ner": "O"
#   },
#   {
#     "id": 24,
#     "text": "All",
#     "lemma": "all",
#     "upos": "DET",
#     "xpos": "DT",
#     "head": 31,
#     "deprel": "nsubj",
#     "start_char": 355,
#     "end_char": 358,
#     "ner": "O"
#   },
#   {
#     "id": 25,
#     "text": "right",
#     "lemma": "right",
#     "upos": "ADV",
#     "xpos": "RB",
#     "head": 27,
#     "deprel": "advmod",
#     "start_char": 359,
#     "end_char": 364,
#     "ner": "O"
#   },
#   {
#     "id": 26,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 27,
#     "deprel": "punct",
#     "start_char": 364,
#     "end_char": 365,
#     "ner": "O"
#   },
#   {
#     "id": 27,
#     "text": "Dolly",
#     "lemma": "Dolly",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "feats": "Number=Sing",
#     "head": 31,
#     "deprel": "vocative",
#     "start_char": 366,
#     "end_char": 371,
#     "ner": "S-PERSON"
#   },
#   {
#     "id": 28,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 27,
#     "deprel": "punct",
#     "start_char": 371,
#     "end_char": 372,
#     "ner": "O"
#   },
#   {
#     "id": 29,
#     "text": "you",
#     "lemma": "you",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Person=2|PronType=Prs",
#     "head": 31,
#     "deprel": "nsubj",
#     "start_char": 373,
#     "end_char": 376,
#     "ner": "O"
#   },
#   {
#     "id": 30,
#     "text": "may",
#     "lemma": "may",
#     "upos": "AUX",
#     "xpos": "MD",
#     "feats": "VerbForm=Fin",
#     "head": 31,
#     "deprel": "aux",
#     "start_char": 377,
#     "end_char": 380,
#     "ner": "O"
#   },
#   {
#     "id": 31,
#     "text": "go",
#     "lemma": "go",
#     "upos": "VERB",
#     "xpos": "VB",
#     "feats": "VerbForm=Inf",
#     "head": 21,
#     "deprel": "ccomp",
#     "start_char": 381,
#     "end_char": 383,
#     "ner": "O"
#   },
#   {
#     "id": 32,
#     "text": ".",
#     "lemma": ".",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 31,
#     "deprel": "punct",
#     "start_char": 383,
#     "end_char": 384,
#     "ner": "O"
#   },
#   {
#     "id": 33,
#     "text": "\"",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "xpos": "''",
#     "head": 31,
#     "deprel": "punct",
#     "start_char": 384,
#     "end_char": 385,
#     "ner": "O"
#   },
#   {
#     "id": 34,
#     "text": "\"",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "xpos": "``",
#     "head": 37,
#     "deprel": "punct",
#     "start_char": 385,
#     "end_char": 386,
#     "ner": "O"
#   },
#   {
#     "id": 35,
#     "text": "Oh",
#     "lemma": "oh",
#     "upos": "INTJ",
#     "xpos": "UH",
#     "head": 37,
#     "deprel": "discourse",
#     "start_char": 386,
#     "end_char": 388,
#     "ner": "O"
#   },
#   {
#     "id": 36,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 35,
#     "deprel": "punct",
#     "start_char": 388,
#     "end_char": 389,
#     "ner": "O"
#   },
#   {
#     "id": 37,
#     "text": "mother",
#     "lemma": "mother",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 31,
#     "deprel": "vocative",
#     "start_char": 390,
#     "end_char": 396,
#     "ner": "O"
#   },
#   {
#     "id": 38,
#     "text": "!",
#     "lemma": "!",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 37,
#     "deprel": "punct",
#     "start_char": 396,
#     "end_char": 397,
#     "ner": "O"
#   },
#   {
#     "id": 39,
#     "text": "\"",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "xpos": "''",
#     "head": 37,
#     "deprel": "punct",
#     "start_char": 397,
#     "end_char": 398,
#     "ner": "O"
#   }
# ]
# ['ADP', 'ADJ', 'PUNCT', 'ADV', 'PUNCT', 'SCONJ', 'DET', 'NOUN', 'AUX', 'ADV', 'ADV', 'PUNCT', 'PRON', 'VERB', 'ADP', 'PRON', 'ADJ', 'NOUN', 'PUNCT', 'CCONJ', 'VERB', 'PUNCT', 'PUNCT', 'DET', 'ADV', 'PUNCT', 'PROPN', 'PUNCT', 'PRON', 'AUX', 'VERB', 'PUNCT', 'PUNCT', 'PUNCT', 'INTJ', 'PUNCT', 'NOUN', 'PUNCT', 'PUNCT']
# [
#   {
#     "id": 1,
#     "text": "Dolly",
#     "lemma": "Dolly",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "feats": "Number=Sing",
#     "head": 2,
#     "deprel": "nsubj",
#     "start_char": 399,
#     "end_char": 404,
#     "ner": "S-PERSON"
#   },
#   {
#     "id": 2,
#     "text": "cried",
#     "lemma": "cry",
#     "upos": "VERB",
#     "xpos": "VBD",
#     "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 405,
#     "end_char": 410,
#     "ner": "O"
#   },
#   {
#     "id": 3,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 4,
#     "deprel": "punct",
#     "start_char": 410,
#     "end_char": 411,
#     "ner": "O"
#   },
#   {
#     "id": 4,
#     "text": "overwhelmed",
#     "lemma": "overwhelm",
#     "upos": "VERB",
#     "xpos": "VBN",
#     "feats": "Tense=Past|VerbForm=Part",
#     "head": 2,
#     "deprel": "advcl",
#     "start_char": 412,
#     "end_char": 423,
#     "ner": "O"
#   },
#   {
#     "id": 5,
#     "text": "with",
#     "lemma": "with",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 7,
#     "deprel": "case",
#     "start_char": 424,
#     "end_char": 428,
#     "ner": "O"
#   },
#   {
#     "id": 6,
#     "text": "sudden",
#     "lemma": "sudden",
#     "upos": "ADJ",
#     "xpos": "JJ",
#     "feats": "Degree=Pos",
#     "head": 7,
#     "deprel": "amod",
#     "start_char": 429,
#     "end_char": 435,
#     "ner": "O"
#   },
#   {
#     "id": 7,
#     "text": "delight",
#     "lemma": "delight",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 4,
#     "deprel": "obl",
#     "start_char": 436,
#     "end_char": 443,
#     "ner": "O"
#   },
#   {
#     "id": 8,
#     "text": ".",
#     "lemma": ".",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 2,
#     "deprel": "punct",
#     "start_char": 443,
#     "end_char": 444,
#     "ner": "O"
#   }
# ]
# ['PROPN', 'VERB', 'PUNCT', 'VERB', 'ADP', 'ADJ', 'NOUN', 'PUNCT']
# [
#   {
#     "id": 1,
#     "text": "\"",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "xpos": "``",
#     "head": 2,
#     "deprel": "punct",
#     "start_char": 445,
#     "end_char": 446,
#     "ner": "O"
#   },
#   {
#     "id": 2,
#     "text": "Really",
#     "lemma": "really",
#     "upos": "ADV",
#     "xpos": "RB",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 446,
#     "end_char": 452,
#     "ner": "O"
#   },
#   {
#     "id": 3,
#     "text": "?",
#     "lemma": "?",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 2,
#     "deprel": "punct",
#     "start_char": 452,
#     "end_char": 453,
#     "ner": "O"
#   }
# ]
# ['PUNCT', 'ADV', 'PUNCT']
# [
#   {
#     "id": 1,
#     "text": "Oh",
#     "lemma": "oh",
#     "upos": "INTJ",
#     "xpos": "UH",
#     "head": 6,
#     "deprel": "discourse",
#     "start_char": 453,
#     "end_char": 455,
#     "ner": "O"
#   },
#   {
#     "id": 2,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 6,
#     "deprel": "punct",
#     "start_char": 455,
#     "end_char": 456,
#     "ner": "O"
#   },
#   {
#     "id": 3,
#     "text": "I",
#     "lemma": "I",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#     "head": 6,
#     "deprel": "nsubj",
#     "start_char": 457,
#     "end_char": 458,
#     "ner": "O"
#   },
#   {
#     "id": 4,
#     "text": "am",
#     "lemma": "be",
#     "upos": "AUX",
#     "xpos": "VBP",
#     "feats": "Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin",
#     "head": 6,
#     "deprel": "cop",
#     "start_char": 459,
#     "end_char": 461,
#     "ner": "O"
#   },
#   {
#     "id": 5,
#     "text": "so",
#     "lemma": "so",
#     "upos": "ADV",
#     "xpos": "RB",
#     "head": 6,
#     "deprel": "advmod",
#     "start_char": 462,
#     "end_char": 464,
#     "ner": "O"
#   },
#   {
#     "id": 6,
#     "text": "glad",
#     "lemma": "glad",
#     "upos": "ADJ",
#     "xpos": "JJ",
#     "feats": "Degree=Pos",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 465,
#     "end_char": 469,
#     "ner": "O"
#   },
#   {
#     "id": 7,
#     "text": "!",
#     "lemma": "!",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 6,
#     "deprel": "punct",
#     "start_char": 469,
#     "end_char": 470,
#     "ner": "O"
#   }
# ]
# ['INTJ', 'PUNCT', 'PRON', 'AUX', 'ADV', 'ADJ', 'PUNCT']
# [
#   {
#     "id": 1,
#     "text": "Are",
#     "lemma": "be",
#     "upos": "AUX",
#     "xpos": "VBP",
#     "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#     "head": 3,
#     "deprel": "cop",
#     "start_char": 471,
#     "end_char": 474,
#     "ner": "O"
#   },
#   {
#     "id": 2,
#     "text": "you",
#     "lemma": "you",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Person=2|PronType=Prs",
#     "head": 3,
#     "deprel": "nsubj",
#     "start_char": 475,
#     "end_char": 478,
#     "ner": "O"
#   },
#   {
#     "id": 3,
#     "text": "sure",
#     "lemma": "sure",
#     "upos": "ADJ",
#     "xpos": "JJ",
#     "feats": "Degree=Pos",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 479,
#     "end_char": 483,
#     "ner": "O"
#   },
#   {
#     "id": 4,
#     "text": "you",
#     "lemma": "you",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Acc|Person=2|PronType=Prs",
#     "head": 3,
#     "deprel": "obj",
#     "start_char": 484,
#     "end_char": 487,
#     "ner": "O"
#   },
#   {
#     "id": 5,
#     "text": "\\",
#     "lemma": "''",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 3,
#     "deprel": "punct",
#     "start_char": 487,
#     "end_char": 488,
#     "ner": "O"
#   },
#   {
#     "id": 6,
#     "text": "'re",
#     "lemma": "be",
#     "upos": "AUX",
#     "xpos": "VBP",
#     "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#     "head": 7,
#     "deprel": "cop",
#     "start_char": 488,
#     "end_char": 491,
#     "ner": "O"
#   },
#   {
#     "id": 7,
#     "text": "willing",
#     "lemma": "willing",
#     "upos": "ADJ",
#     "xpos": "JJ",
#     "feats": "Degree=Pos",
#     "head": 3,
#     "deprel": "ccomp",
#     "start_char": 492,
#     "end_char": 499,
#     "ner": "O"
#   },
#   {
#     "id": 8,
#     "text": "?",
#     "lemma": "?",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 7,
#     "deprel": "punct",
#     "start_char": 499,
#     "end_char": 500,
#     "ner": "O"
#   },
#   {
#     "id": 9,
#     "text": "\"",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "xpos": "''",
#     "head": 3,
#     "deprel": "punct",
#     "start_char": 500,
#     "end_char": 501,
#     "ner": "O"
#   },
#   {
#     "id": 10,
#     "text": "\"",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "xpos": "``",
#     "head": 14,
#     "deprel": "punct",
#     "start_char": 501,
#     "end_char": 502,
#     "ner": "O"
#   },
#   {
#     "id": 11,
#     "text": "I",
#     "lemma": "I",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#     "head": 14,
#     "deprel": "nsubj",
#     "start_char": 502,
#     "end_char": 503,
#     "ner": "O"
#   },
#   {
#     "id": 12,
#     "text": "\\",
#     "lemma": "''",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 11,
#     "deprel": "punct",
#     "start_char": 503,
#     "end_char": 504,
#     "ner": "O"
#   },
#   {
#     "id": 13,
#     "text": "'ve",
#     "lemma": "have",
#     "upos": "AUX",
#     "xpos": "VBP",
#     "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#     "head": 14,
#     "deprel": "aux",
#     "start_char": 504,
#     "end_char": 507,
#     "ner": "O"
#   },
#   {
#     "id": 14,
#     "text": "persuaded",
#     "lemma": "persuade",
#     "upos": "VERB",
#     "xpos": "VBN",
#     "feats": "Tense=Past|VerbForm=Part",
#     "head": 3,
#     "deprel": "parataxis",
#     "start_char": 508,
#     "end_char": 517,
#     "ner": "O"
#   },
#   {
#     "id": 15,
#     "text": "myself",
#     "lemma": "myself",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Acc|Number=Sing|Person=1|PronType=Prs|Reflex=Yes",
#     "head": 14,
#     "deprel": "obj",
#     "start_char": 518,
#     "end_char": 524,
#     "ner": "O"
#   },
#   {
#     "id": 16,
#     "text": "to",
#     "lemma": "to",
#     "upos": "PART",
#     "xpos": "TO",
#     "head": 18,
#     "deprel": "mark",
#     "start_char": 525,
#     "end_char": 527,
#     "ner": "O"
#   },
#   {
#     "id": 17,
#     "text": "be",
#     "lemma": "be",
#     "upos": "AUX",
#     "xpos": "VB",
#     "feats": "VerbForm=Inf",
#     "head": 18,
#     "deprel": "cop",
#     "start_char": 528,
#     "end_char": 530,
#     "ner": "O"
#   },
#   {
#     "id": 18,
#     "text": "willing",
#     "lemma": "willing",
#     "upos": "ADJ",
#     "xpos": "JJ",
#     "feats": "Degree=Pos",
#     "head": 14,
#     "deprel": "xcomp",
#     "start_char": 531,
#     "end_char": 538,
#     "ner": "O"
#   },
#   {
#     "id": 19,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 25,
#     "deprel": "punct",
#     "start_char": 538,
#     "end_char": 539,
#     "ner": "O"
#   },
#   {
#     "id": 20,
#     "text": "against",
#     "lemma": "against",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 22,
#     "deprel": "case",
#     "start_char": 540,
#     "end_char": 547,
#     "ner": "O"
#   },
#   {
#     "id": 21,
#     "text": "my",
#     "lemma": "my",
#     "upos": "PRON",
#     "xpos": "PRP$",
#     "feats": "Number=Sing|Person=1|Poss=Yes|PronType=Prs",
#     "head": 22,
#     "deprel": "nmod:poss",
#     "start_char": 548,
#     "end_char": 550,
#     "ner": "O"
#   },
#   {
#     "id": 22,
#     "text": "will",
#     "lemma": "will",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 18,
#     "deprel": "obl",
#     "start_char": 551,
#     "end_char": 555,
#     "ner": "O"
#   },
#   {
#     "id": 23,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 25,
#     "deprel": "punct",
#     "start_char": 555,
#     "end_char": 556,
#     "ner": "O"
#   },
#   {
#     "id": 24,
#     "text": "\"",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "xpos": "''",
#     "head": 25,
#     "deprel": "punct",
#     "start_char": 556,
#     "end_char": 557,
#     "ner": "O"
#   },
#   {
#     "id": 25,
#     "text": "returned",
#     "lemma": "return",
#     "upos": "VERB",
#     "xpos": "VBD",
#     "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#     "head": 14,
#     "deprel": "parataxis",
#     "start_char": 558,
#     "end_char": 566,
#     "ner": "O"
#   },
#   {
#     "id": 26,
#     "text": "Mrs.",
#     "lemma": "Mrs.",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "feats": "Number=Sing",
#     "head": 25,
#     "deprel": "nsubj",
#     "start_char": 567,
#     "end_char": 571,
#     "ner": "O"
#   },
#   {
#     "id": 27,
#     "text": "Fayre",
#     "lemma": "Fayre",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "feats": "Number=Sing",
#     "head": 26,
#     "deprel": "flat",
#     "start_char": 572,
#     "end_char": 577,
#     "ner": "S-PERSON"
#   },
#   {
#     "id": 28,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 26,
#     "deprel": "punct",
#     "start_char": 577,
#     "end_char": 578,
#     "ner": "O"
#   },
#   {
#     "id": 29,
#     "text": "whimsically",
#     "lemma": "whimsically",
#     "upos": "ADV",
#     "xpos": "RB",
#     "head": 25,
#     "deprel": "advmod",
#     "start_char": 579,
#     "end_char": 590,
#     "ner": "O"
#   },
#   {
#     "id": 30,
#     "text": ".",
#     "lemma": ".",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 25,
#     "deprel": "punct",
#     "start_char": 590,
#     "end_char": 591,
#     "ner": "O"
#   }
# ]
# ['AUX', 'PRON', 'ADJ', 'PRON', 'PUNCT', 'AUX', 'ADJ', 'PUNCT', 'PUNCT', 'PUNCT', 'PRON', 'PUNCT', 'AUX', 'VERB', 'PRON', 'PART', 'AUX', 'ADJ', 'PUNCT', 'ADP', 'PRON', 'NOUN', 'PUNCT', 'PUNCT', 'VERB', 'PROPN', 'PROPN', 'PUNCT', 'ADV', 'PUNCT']
# [
#   {
#     "id": 1,
#     "text": "\"",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "xpos": "``",
#     "head": 3,
#     "deprel": "punct",
#     "start_char": 592,
#     "end_char": 593,
#     "ner": "O"
#   },
#   {
#     "id": 2,
#     "text": "I",
#     "lemma": "I",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#     "head": 3,
#     "deprel": "nsubj",
#     "start_char": 593,
#     "end_char": 594,
#     "ner": "O"
#   },
#   {
#     "id": 3,
#     "text": "confess",
#     "lemma": "confess",
#     "upos": "VERB",
#     "xpos": "VBP",
#     "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 595,
#     "end_char": 602,
#     "ner": "O"
#   },
#   {
#     "id": 4,
#     "text": "I",
#     "lemma": "I",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#     "head": 6,
#     "deprel": "nsubj",
#     "start_char": 603,
#     "end_char": 604,
#     "ner": "O"
#   },
#   {
#     "id": 5,
#     "text": "just",
#     "lemma": "just",
#     "upos": "ADV",
#     "xpos": "RB",
#     "head": 6,
#     "deprel": "advmod",
#     "start_char": 605,
#     "end_char": 609,
#     "ner": "O"
#   },
#   {
#     "id": 6,
#     "text": "hate",
#     "lemma": "hate",
#     "upos": "VERB",
#     "xpos": "VBP",
#     "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#     "head": 3,
#     "deprel": "ccomp",
#     "start_char": 610,
#     "end_char": 614,
#     "ner": "O"
#   },
#   {
#     "id": 7,
#     "text": "to",
#     "lemma": "to",
#     "upos": "PART",
#     "xpos": "TO",
#     "head": 8,
#     "deprel": "mark",
#     "start_char": 615,
#     "end_char": 617,
#     "ner": "O"
#   },
#   {
#     "id": 8,
#     "text": "have",
#     "lemma": "have",
#     "upos": "VERB",
#     "xpos": "VB",
#     "feats": "VerbForm=Inf",
#     "head": 6,
#     "deprel": "xcomp",
#     "start_char": 618,
#     "end_char": 622,
#     "ner": "O"
#   },
#   {
#     "id": 9,
#     "text": "you",
#     "lemma": "you",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Person=2|PronType=Prs",
#     "head": 10,
#     "deprel": "nsubj",
#     "start_char": 623,
#     "end_char": 626,
#     "ner": "O"
#   },
#   {
#     "id": 10,
#     "text": "go",
#     "lemma": "go",
#     "upos": "VERB",
#     "xpos": "VB",
#     "feats": "VerbForm=Inf",
#     "head": 8,
#     "deprel": "ccomp",
#     "start_char": 627,
#     "end_char": 629,
#     "ner": "O"
#   },
#   {
#     "id": 11,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 16,
#     "deprel": "punct",
#     "start_char": 629,
#     "end_char": 630,
#     "ner": "O"
#   },
#   {
#     "id": 12,
#     "text": "but",
#     "lemma": "but",
#     "upos": "CCONJ",
#     "xpos": "CC",
#     "head": 16,
#     "deprel": "cc",
#     "start_char": 631,
#     "end_char": 634,
#     "ner": "O"
#   },
#   {
#     "id": 13,
#     "text": "I",
#     "lemma": "I",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#     "head": 16,
#     "deprel": "nsubj",
#     "start_char": 635,
#     "end_char": 636,
#     "ner": "O"
#   },
#   {
#     "id": 14,
#     "text": "can",
#     "lemma": "can",
#     "upos": "AUX",
#     "xpos": "MD",
#     "feats": "VerbForm=Fin",
#     "head": 16,
#     "deprel": "aux",
#     "start_char": 637,
#     "end_char": 640,
#     "ner": "O"
#   },
#   {
#     "id": 15,
#     "text": "\\'t",
#     "lemma": "not",
#     "upos": "PART",
#     "xpos": "RB",
#     "head": 16,
#     "deprel": "advmod",
#     "start_char": 640,
#     "end_char": 643,
#     "ner": "O"
#   },
#   {
#     "id": 16,
#     "text": "bear",
#     "lemma": "bear",
#     "upos": "VERB",
#     "xpos": "VB",
#     "feats": "VerbForm=Inf",
#     "head": 3,
#     "deprel": "conj",
#     "start_char": 644,
#     "end_char": 648,
#     "ner": "O"
#   },
#   {
#     "id": 17,
#     "text": "to",
#     "lemma": "to",
#     "upos": "PART",
#     "xpos": "TO",
#     "head": 18,
#     "deprel": "mark",
#     "start_char": 649,
#     "end_char": 651,
#     "ner": "O"
#   },
#   {
#     "id": 18,
#     "text": "deprive",
#     "lemma": "deprive",
#     "upos": "VERB",
#     "xpos": "VB",
#     "feats": "VerbForm=Inf",
#     "head": 16,
#     "deprel": "xcomp",
#     "start_char": 652,
#     "end_char": 659,
#     "ner": "O"
#   },
#   {
#     "id": 19,
#     "text": "you",
#     "lemma": "you",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Acc|Person=2|PronType=Prs",
#     "head": 18,
#     "deprel": "obj",
#     "start_char": 660,
#     "end_char": 663,
#     "ner": "O"
#   },
#   {
#     "id": 20,
#     "text": "of",
#     "lemma": "of",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 23,
#     "deprel": "case",
#     "start_char": 664,
#     "end_char": 666,
#     "ner": "O"
#   },
#   {
#     "id": 21,
#     "text": "the",
#     "lemma": "the",
#     "upos": "DET",
#     "xpos": "DT",
#     "feats": "Definite=Def|PronType=Art",
#     "head": 23,
#     "deprel": "det",
#     "start_char": 667,
#     "end_char": 670,
#     "ner": "O"
#   },
#   {
#     "id": 22,
#     "text": "pleasure",
#     "lemma": "pleasure",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 23,
#     "deprel": "compound",
#     "start_char": 671,
#     "end_char": 679,
#     "ner": "O"
#   },
#   {
#     "id": 23,
#     "text": "trip",
#     "lemma": "trip",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 18,
#     "deprel": "obl",
#     "start_char": 680,
#     "end_char": 684,
#     "ner": "O"
#   },
#   {
#     "id": 24,
#     "text": ".",
#     "lemma": ".",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 3,
#     "deprel": "punct",
#     "start_char": 684,
#     "end_char": 685,
#     "ner": "O"
#   }
# ]
# ['PUNCT', 'PRON', 'VERB', 'PRON', 'ADV', 'VERB', 'PART', 'VERB', 'PRON', 'VERB', 'PUNCT', 'CCONJ', 'PRON', 'AUX', 'PART', 'VERB', 'PART', 'VERB', 'PRON', 'ADP', 'DET', 'NOUN', 'NOUN', 'PUNCT']
# [
#   {
#     "id": 1,
#     "text": "And",
#     "lemma": "and",
#     "upos": "CCONJ",
#     "xpos": "CC",
#     "head": 10,
#     "deprel": "cc",
#     "start_char": 686,
#     "end_char": 689,
#     "ner": "O"
#   },
#   {
#     "id": 2,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 10,
#     "deprel": "punct",
#     "start_char": 689,
#     "end_char": 690,
#     "ner": "O"
#   },
#   {
#     "id": 3,
#     "text": "as",
#     "lemma": "as",
#     "upos": "SCONJ",
#     "xpos": "IN",
#     "head": 5,
#     "deprel": "mark",
#     "start_char": 691,
#     "end_char": 693,
#     "ner": "O"
#   },
#   {
#     "id": 4,
#     "text": "you",
#     "lemma": "you",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Number=Sing|Person=2|PronType=Prs",
#     "head": 5,
#     "deprel": "nsubj",
#     "start_char": 694,
#     "end_char": 697,
#     "ner": "O"
#   },
#   {
#     "id": 5,
#     "text": "say",
#     "lemma": "say",
#     "upos": "VERB",
#     "xpos": "VBP",
#     "feats": "Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin",
#     "head": 10,
#     "deprel": "advcl",
#     "start_char": 698,
#     "end_char": 701,
#     "ner": "O"
#   },
#   {
#     "id": 6,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 10,
#     "deprel": "punct",
#     "start_char": 701,
#     "end_char": 702,
#     "ner": "O"
#   },
#   {
#     "id": 7,
#     "text": "it",
#     "lemma": "it",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Gender=Neut|Number=Sing|Person=3|PronType=Prs",
#     "head": 10,
#     "deprel": "nsubj",
#     "start_char": 703,
#     "end_char": 705,
#     "ner": "O"
#   },
#   {
#     "id": 8,
#     "text": "would",
#     "lemma": "would",
#     "upos": "AUX",
#     "xpos": "MD",
#     "feats": "VerbForm=Fin",
#     "head": 10,
#     "deprel": "aux",
#     "start_char": 706,
#     "end_char": 711,
#     "ner": "O"
#   },
#   {
#     "id": 9,
#     "text": "also",
#     "lemma": "also",
#     "upos": "ADV",
#     "xpos": "RB",
#     "head": 10,
#     "deprel": "advmod",
#     "start_char": 712,
#     "end_char": 716,
#     "ner": "O"
#   },
#   {
#     "id": 10,
#     "text": "keep",
#     "lemma": "keep",
#     "upos": "VERB",
#     "xpos": "VB",
#     "feats": "VerbForm=Inf",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 717,
#     "end_char": 721,
#     "ner": "O"
#   },
#   {
#     "id": 11,
#     "text": "Dotty",
#     "lemma": "Dotty",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "feats": "Number=Sing",
#     "head": 10,
#     "deprel": "obj",
#     "start_char": 722,
#     "end_char": 727,
#     "ner": "S-PERSON"
#   },
#   {
#     "id": 12,
#     "text": "at",
#     "lemma": "at",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 13,
#     "deprel": "case",
#     "start_char": 728,
#     "end_char": 730,
#     "ner": "O"
#   },
#   {
#     "id": 13,
#     "text": "home",
#     "lemma": "home",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 10,
#     "deprel": "obl",
#     "start_char": 731,
#     "end_char": 735,
#     "ner": "O"
#   },
#   {
#     "id": 14,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 21,
#     "deprel": "punct",
#     "start_char": 735,
#     "end_char": 736,
#     "ner": "O"
#   },
#   {
#     "id": 15,
#     "text": "and",
#     "lemma": "and",
#     "upos": "CCONJ",
#     "xpos": "CC",
#     "head": 21,
#     "deprel": "cc",
#     "start_char": 737,
#     "end_char": 740,
#     "ner": "O"
#   },
#   {
#     "id": 16,
#     "text": "so",
#     "lemma": "so",
#     "upos": "ADV",
#     "xpos": "RB",
#     "head": 21,
#     "deprel": "advmod",
#     "start_char": 741,
#     "end_char": 743,
#     "ner": "O"
#   },
#   {
#     "id": 17,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 18,
#     "deprel": "punct",
#     "start_char": 743,
#     "end_char": 744,
#     "ner": "O"
#   },
#   {
#     "id": 18,
#     "text": "altogether",
#     "lemma": "altogether",
#     "upos": "ADV",
#     "xpos": "RB",
#     "feats": "Degree=Pos",
#     "head": 21,
#     "deprel": "advmod",
#     "start_char": 745,
#     "end_char": 755,
#     "ner": "O"
#   },
#   {
#     "id": 19,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 18,
#     "deprel": "punct",
#     "start_char": 755,
#     "end_char": 756,
#     "ner": "O"
#   },
#   {
#     "id": 20,
#     "text": "I",
#     "lemma": "I",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#     "head": 21,
#     "deprel": "nsubj",
#     "start_char": 757,
#     "end_char": 758,
#     "ner": "O"
#   },
#   {
#     "id": 21,
#     "text": "think",
#     "lemma": "think",
#     "upos": "VERB",
#     "xpos": "VBP",
#     "feats": "Mood=Ind|Number=Sing|Person=1|Tense=Pres|VerbForm=Fin",
#     "head": 10,
#     "deprel": "parataxis",
#     "start_char": 759,
#     "end_char": 764,
#     "ner": "O"
#   },
#   {
#     "id": 22,
#     "text": "I",
#     "lemma": "I",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Number=Sing|Person=1|PronType=Prs",
#     "head": 24,
#     "deprel": "nsubj",
#     "start_char": 765,
#     "end_char": 766,
#     "ner": "O"
#   },
#   {
#     "id": 23,
#     "text": "shall",
#     "lemma": "shall",
#     "upos": "AUX",
#     "xpos": "MD",
#     "feats": "VerbForm=Fin",
#     "head": 24,
#     "deprel": "aux",
#     "start_char": 767,
#     "end_char": 772,
#     "ner": "O"
#   },
#   {
#     "id": 24,
#     "text": "have",
#     "lemma": "have",
#     "upos": "VERB",
#     "xpos": "VB",
#     "feats": "VerbForm=Inf",
#     "head": 21,
#     "deprel": "ccomp",
#     "start_char": 773,
#     "end_char": 777,
#     "ner": "O"
#   },
#   {
#     "id": 25,
#     "text": "to",
#     "lemma": "to",
#     "upos": "PART",
#     "xpos": "TO",
#     "head": 26,
#     "deprel": "mark",
#     "start_char": 778,
#     "end_char": 780,
#     "ner": "O"
#   },
#   {
#     "id": 26,
#     "text": "give",
#     "lemma": "give",
#     "upos": "VERB",
#     "xpos": "VB",
#     "feats": "VerbForm=Inf",
#     "head": 24,
#     "deprel": "xcomp",
#     "start_char": 781,
#     "end_char": 785,
#     "ner": "O"
#   },
#   {
#     "id": 27,
#     "text": "in",
#     "lemma": "in",
#     "upos": "ADP",
#     "xpos": "RP",
#     "head": 26,
#     "deprel": "compound:prt",
#     "start_char": 786,
#     "end_char": 788,
#     "ner": "O"
#   },
#   {
#     "id": 28,
#     "text": ".",
#     "lemma": ".",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 21,
#     "deprel": "punct",
#     "start_char": 788,
#     "end_char": 789,
#     "ner": "O"
#   },
#   {
#     "id": 29,
#     "text": "\"",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "xpos": "''",
#     "head": 34,
#     "deprel": "punct",
#     "start_char": 789,
#     "end_char": 790,
#     "ner": "O"
#   },
#   {
#     "id": 30,
#     "text": "\"",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "xpos": "``",
#     "head": 34,
#     "deprel": "punct",
#     "start_char": 790,
#     "end_char": 791,
#     "ner": "O"
#   },
#   {
#     "id": 31,
#     "text": "Oh",
#     "lemma": "oh",
#     "upos": "INTJ",
#     "xpos": "UH",
#     "head": 34,
#     "deprel": "discourse",
#     "start_char": 791,
#     "end_char": 793,
#     "ner": "O"
#   },
#   {
#     "id": 32,
#     "text": ",",
#     "lemma": ",",
#     "upos": "PUNCT",
#     "xpos": ",",
#     "head": 31,
#     "deprel": "punct",
#     "start_char": 793,
#     "end_char": 794,
#     "ner": "O"
#   },
#   {
#     "id": 33,
#     "text": "you",
#     "lemma": "you",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Number=Sing|Person=2|PronType=Prs",
#     "head": 34,
#     "deprel": "nsubj",
#     "start_char": 795,
#     "end_char": 798,
#     "ner": "O"
#   },
#   {
#     "id": 34,
#     "text": "angel",
#     "lemma": "angel",
#     "upos": "VERB",
#     "xpos": "VBP",
#     "feats": "Mood=Ind|Number=Sing|Person=2|Tense=Pres|VerbForm=Fin",
#     "head": 10,
#     "deprel": "parataxis",
#     "start_char": 799,
#     "end_char": 804,
#     "ner": "O"
#   },
#   {
#     "id": 35,
#     "text": "mother",
#     "lemma": "mother",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 34,
#     "deprel": "obj",
#     "start_char": 805,
#     "end_char": 811,
#     "ner": "O"
#   },
#   {
#     "id": 36,
#     "text": "!",
#     "lemma": "!",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 10,
#     "deprel": "punct",
#     "start_char": 811,
#     "end_char": 812,
#     "ner": "O"
#   }
# ]
# ['CCONJ', 'PUNCT', 'SCONJ', 'PRON', 'VERB', 'PUNCT', 'PRON', 'AUX', 'ADV', 'VERB', 'PROPN', 'ADP', 'NOUN', 'PUNCT', 'CCONJ', 'ADV', 'PUNCT', 'ADV', 'PUNCT', 'PRON', 'VERB', 'PRON', 'AUX', 'VERB', 'PART', 'VERB', 'ADP', 'PUNCT', 'PUNCT', 'PUNCT', 'INTJ', 'PUNCT', 'PRON', 'VERB', 'NOUN', 'PUNCT']
# [
#   {
#     "id": 1,
#     "text": "You",
#     "lemma": "you",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Person=2|PronType=Prs",
#     "head": 2,
#     "deprel": "nsubj",
#     "start_char": 813,
#     "end_char": 816,
#     "ner": "O"
#   },
#   {
#     "id": 2,
#     "text": "blessed",
#     "lemma": "bless",
#     "upos": "VERB",
#     "xpos": "VBD",
#     "feats": "Mood=Ind|Tense=Past|VerbForm=Fin",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 817,
#     "end_char": 824,
#     "ner": "O"
#   },
#   {
#     "id": 3,
#     "text": "lady",
#     "lemma": "lady",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 2,
#     "deprel": "obj",
#     "start_char": 825,
#     "end_char": 829,
#     "ner": "O"
#   },
#   {
#     "id": 4,
#     "text": "!",
#     "lemma": "!",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 2,
#     "deprel": "punct",
#     "start_char": 829,
#     "end_char": 830,
#     "ner": "O"
#   }
# ]
# ['PRON', 'VERB', 'NOUN', 'PUNCT']
# [
#   {
#     "id": 1,
#     "text": "How",
#     "lemma": "how",
#     "upos": "ADV",
#     "xpos": "WRB",
#     "feats": "PronType=Int",
#     "head": 2,
#     "deprel": "advmod",
#     "start_char": 831,
#     "end_char": 834,
#     "ner": "O"
#   },
#   {
#     "id": 2,
#     "text": "good",
#     "lemma": "good",
#     "upos": "ADJ",
#     "xpos": "JJ",
#     "feats": "Degree=Pos",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 835,
#     "end_char": 839,
#     "ner": "O"
#   },
#   {
#     "id": 3,
#     "text": "you",
#     "lemma": "you",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Nom|Number=Sing|Person=2|PronType=Prs",
#     "head": 4,
#     "deprel": "nsubj",
#     "start_char": 840,
#     "end_char": 843,
#     "ner": "O"
#   },
#   {
#     "id": 4,
#     "text": "are",
#     "lemma": "be",
#     "upos": "AUX",
#     "xpos": "VBP",
#     "feats": "Mood=Ind|Tense=Pres|VerbForm=Fin",
#     "head": 2,
#     "deprel": "cop",
#     "start_char": 844,
#     "end_char": 847,
#     "ner": "O"
#   },
#   {
#     "id": 5,
#     "text": "!",
#     "lemma": "!",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 2,
#     "deprel": "punct",
#     "start_char": 847,
#     "end_char": 848,
#     "ner": "O"
#   },
#   {
#     "id": 6,
#     "text": "\"",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "xpos": "''",
#     "head": 2,
#     "deprel": "punct",
#     "start_char": 848,
#     "end_char": 849,
#     "ner": "O"
#   }
# ]
# ['ADV', 'ADJ', 'PRON', 'AUX', 'PUNCT', 'PUNCT']
# [
#   {
#     "id": 1,
#     "text": "And",
#     "lemma": "and",
#     "upos": "CCONJ",
#     "xpos": "CC",
#     "head": 3,
#     "deprel": "cc",
#     "start_char": 850,
#     "end_char": 853,
#     "ner": "O"
#   },
#   {
#     "id": 2,
#     "text": "Dolly",
#     "lemma": "Dolly",
#     "upos": "PROPN",
#     "xpos": "NNP",
#     "feats": "Number=Sing",
#     "head": 3,
#     "deprel": "nsubj",
#     "start_char": 854,
#     "end_char": 859,
#     "ner": "S-PERSON"
#   },
#   {
#     "id": 3,
#     "text": "flew",
#     "lemma": "fly",
#     "upos": "VERB",
#     "xpos": "VBD",
#     "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 860,
#     "end_char": 864,
#     "ner": "O"
#   },
#   {
#     "id": 4,
#     "text": "around",
#     "lemma": "around",
#     "upos": "ADP",
#     "xpos": "IN",
#     "head": 6,
#     "deprel": "case",
#     "start_char": 865,
#     "end_char": 871,
#     "ner": "O"
#   },
#   {
#     "id": 5,
#     "text": "the",
#     "lemma": "the",
#     "upos": "DET",
#     "xpos": "DT",
#     "feats": "Definite=Def|PronType=Art",
#     "head": 6,
#     "deprel": "det",
#     "start_char": 872,
#     "end_char": 875,
#     "ner": "O"
#   },
#   {
#     "id": 6,
#     "text": "table",
#     "lemma": "table",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 3,
#     "deprel": "obl",
#     "start_char": 876,
#     "end_char": 881,
#     "ner": "O"
#   },
#   {
#     "id": 7,
#     "text": "and",
#     "lemma": "and",
#     "upos": "CCONJ",
#     "xpos": "CC",
#     "head": 8,
#     "deprel": "cc",
#     "start_char": 882,
#     "end_char": 885,
#     "ner": "O"
#   },
#   {
#     "id": 8,
#     "text": "gave",
#     "lemma": "give",
#     "upos": "VERB",
#     "xpos": "VBD",
#     "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#     "head": 3,
#     "deprel": "conj",
#     "start_char": 886,
#     "end_char": 890,
#     "ner": "O"
#   },
#   {
#     "id": 9,
#     "text": "her",
#     "lemma": "she",
#     "upos": "PRON",
#     "xpos": "PRP$",
#     "feats": "Gender=Fem|Number=Sing|Person=3|Poss=Yes|PronType=Prs",
#     "head": 10,
#     "deprel": "nmod:poss",
#     "start_char": 891,
#     "end_char": 894,
#     "ner": "O"
#   },
#   {
#     "id": 10,
#     "text": "mother",
#     "lemma": "mother",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 8,
#     "deprel": "iobj",
#     "start_char": 895,
#     "end_char": 901,
#     "ner": "O"
#   },
#   {
#     "id": 11,
#     "text": "a",
#     "lemma": "a",
#     "upos": "DET",
#     "xpos": "DT",
#     "feats": "Definite=Ind|PronType=Art",
#     "head": 12,
#     "deprel": "det",
#     "start_char": 902,
#     "end_char": 903,
#     "ner": "O"
#   },
#   {
#     "id": 12,
#     "text": "hug",
#     "lemma": "hug",
#     "upos": "NOUN",
#     "xpos": "NN",
#     "feats": "Number=Sing",
#     "head": 8,
#     "deprel": "obj",
#     "start_char": 904,
#     "end_char": 907,
#     "ner": "O"
#   },
#   {
#     "id": 13,
#     "text": "that",
#     "lemma": "that",
#     "upos": "PRON",
#     "xpos": "WDT",
#     "feats": "PronType=Rel",
#     "head": 15,
#     "deprel": "nsubj",
#     "start_char": 908,
#     "end_char": 912,
#     "ner": "O"
#   },
#   {
#     "id": 14,
#     "text": "nearly",
#     "lemma": "nearly",
#     "upos": "ADV",
#     "xpos": "RB",
#     "feats": "Degree=Pos",
#     "head": 15,
#     "deprel": "advmod",
#     "start_char": 913,
#     "end_char": 919,
#     "ner": "O"
#   },
#   {
#     "id": 15,
#     "text": "suffocated",
#     "lemma": "suffocate",
#     "upos": "VERB",
#     "xpos": "VBD",
#     "feats": "Mood=Ind|Number=Sing|Person=3|Tense=Past|VerbForm=Fin",
#     "head": 12,
#     "deprel": "acl:relcl",
#     "start_char": 920,
#     "end_char": 930,
#     "ner": "O"
#   },
#   {
#     "id": 16,
#     "text": "her",
#     "lemma": "she",
#     "upos": "PRON",
#     "xpos": "PRP",
#     "feats": "Case=Acc|Gender=Fem|Number=Sing|Person=3|PronType=Prs",
#     "head": 15,
#     "deprel": "obj",
#     "start_char": 931,
#     "end_char": 934,
#     "ner": "O"
#   },
#   {
#     "id": 17,
#     "text": ".",
#     "lemma": ".",
#     "upos": "PUNCT",
#     "xpos": ".",
#     "head": 3,
#     "deprel": "punct",
#     "start_char": 934,
#     "end_char": 935,
#     "ner": "O"
#   }
# ]
# ['CCONJ', 'PROPN', 'VERB', 'ADP', 'DET', 'NOUN', 'CCONJ', 'VERB', 'PRON', 'NOUN', 'DET', 'NOUN', 'PRON', 'ADV', 'VERB', 'PRON', 'PUNCT']
